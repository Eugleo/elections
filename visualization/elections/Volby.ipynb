# %% [markdown]
# # Výsledky voleb do PS a rozdělení mandátů 1996–2017
#
# Zpracujeme výsledky voleb do Poslanecké sněmovny ČR od roku 1996 až do roku 2017. Použijeme k tomu data z ČSÚ, která stáhneme přímo z jejich webu.

# %%
import re
import csv
import json
from requests_html import HTMLSession

from requests_html import Element
from typing import Dict, List, Any

# %%
def safe_parse_int(s):
    string = ''.join(c for c in s if c.isdigit())
    return int(string) if string.isdigit() else 0

# %% [markdown]
# ## Roky 1993 a 1996

# %% [markdown]
# Získání samotných výsledků jednotlivých stran ze stránky s tabulkou počtu hlasů:

# %%
def scrape_results(url):
    session = HTMLSession()
    html = session.get(url).html
    html.encoding = 'ISO-8859-2'
    tables = html.find('table')
    
    return (parse_parties(tables[1]), parse_stats(tables[0]))


def parse_stats(table):
    data = table.find('tr > td')
    return {
        'registered': safe_parse_int(data[3].text), 
        'given': safe_parse_int(data[6].text), 
        'ok': safe_parse_int(data[7].text)
    }

    
def parse_parties(table):
    rows = table.find('tr')
    
    parties = []
    for row in rows:
        if not row.find('th'):
            parties.extend(parse_pair(row))
            
    return parties
    
    
def parse_pair(row):
    cells = row.find('td')
    parties = []
    parties.append({
        'name': cells[1].text, 
        'votes': safe_parse_int(cells[2].text)
    })
    
    if len(cells) >= 7:
        parties.append({
            'name': cells[6].text,
            'votes': safe_parse_int(cells[7].text)
        })
        
    return parties
    
    
def safe_parse_int(s):
    string = ''.join(c for c in s if c.isdigit())
    return int(string) if string.isdigit() else 0

# %% [markdown]
# Získání stránky s tabulkou výsledků:
#
# `rok > výsledky za územní celky > výběr obce > výsledky za obec`
#
# př: 1996 > Kolín > Barchovice > výsledky za obec

# %%
def scrape_counties02(url):
    session = HTMLSession()
    html = session.get(url).html
    html.encoding = 'ISO-8859-2'
    year = get_year(url)
    table = html.find('table', first=True)
    base = get_base_url(url)
    if year <= 1998:
        func = scrape_county98
    elif year == 2002:
        func = scrape_county02

    region = ''
    result = []
    for row in table.find('tr'):
        if len(row.find('td')) == 1:
            region = row.find('td', first=True).text
        elif len(row.find('td')) > 2:
            result.extend(func(row, region=region, year=year, base=base))
            
    return result


def scrape_county98(row, region='', year=0, base=''):
    county = row.find('td')[1].text
    site = row.find('a', containing='X', first=True).attrs['href']
    towns = scrape_towns98(base + site, region=region, county=county, year=year)
    print(f"Written {len(towns)} towns from {county}, {region}  ({year})")
    return towns


def scrape_county02(row, region='', year=0, base=''):
    county = row.find('td')[1].text
    site = row.find('a')[2].attrs['href']
    towns = scrape_towns02(base + site, region=region, county=county, year=year)
    print(f"Written {len(towns)} towns from {county}, {region}  ({year})")
    return towns


def scrape_towns98(url, region='', county='', year=0):
    session = HTMLSession()
    html = session.get(url).html
    html.encoding = 'ISO-8859-2'
    table = html.find('table', first=True)
    base = get_base_url(url)

    result = []
    for row in table.find('tr'):
        if row.find('td'):
            name = row.find('td')[1].text
            try:
                site = row.find('a', first=True).attrs['href']
                parties, stats = scrape_results(base + site)
                result.append({
                    'year': year,
                    'region': region,
                    'county': county,
                    'town': name,
                    'parties': parties,
                    'stats': stats
                })
            except:
                print(f"Failed to parse town {name} from {county}, {region}")
    return result


def scrape_towns02(url, region='', county='', year=0):
    session = HTMLSession()
    html = session.get(url).html
    html.encoding = 'ISO-8859-2'
    table = html.find('table', first=True)
    base = get_base_url(url)
    
    result = []
    for row in table.find('tr'):
        if len(row.find('td')) > 1:
            links = row.find('a')
            parties, stats = scrape_results(base + links[0].attrs['href'])
            result.append({
                'year': year,
                'region': region,
                'county': county,
                'town': row.find('td')[1].text,
                'parties': parties,
                'stats': stats
            })
            
            if len(links) > 2:
                parties, stats = scrape_results(base + links[2].attrs['href'])
                result.append({
                    'year': year,
                    'region': region,
                    'county': county,
                    'town': row.find('td')[5].text,
                    'parties': parties,
                    'stats': stats
                })

    return result


def get_base_url(url):
    return re.match(re.compile(r'^.+\/'), url).group()


def get_town_url(row, year):
    if year <= 2002:
        return row.find('a', first=True).attrs['href']

# %%
def scrape_counties17(url) -> List[Dict[str, Any]]:
    session = HTMLSession()
    html = session.get(url).html
    html.encoding = 'ISO-8859-2'
    base_url = get_base_url(url)
    year = get_year(url)
    regions = get_regions(html)
    tables = html.find('table.table')
    return concatenate(
        scrape_region(tb, region=rg, year=year, base_url=base_url)
        for rg, tb in zip(regions, tables)
    )
    

def get_regions(html) -> List[Element]:
    regs = html.find('h3.kraj')
    return [r.find('a', first=True).text for r in regs]


def scrape_region(table, *, region, year, base_url) -> List[Dict[str, Any]]:
    rows = table.find('tr')
    return concatenate(
        scrape_county(c, region=region, year=year, base_url=base_url) 
        for c in rows 
        if not c.find('th')
    )


def scrape_county(row, *, region, year, base_url) -> List[Dict[str, Any]]:
    tds = row.find('td')
    county_name = tds[1].text
    towns_link = tds[3].find('a', first=True).attrs['href']
    res = scrape_towns(base_url + towns_link, region=region, county=county_name, year=year, base_url=base_url)
    print(f"Scraped {len(res)} towns in county {county_name}, {region}")
    return res
    
    
def scrape_towns(url, *, region, county, year, base_url) -> List[Dict[str, Any]]:
    session = HTMLSession()
    html = session.get(url).html
    html.encoding = 'ISO-8859-2'
    tables = html.find('table.table')
    
    result = []
    for tb in tables:
        for town in tb.xpath('//tr[count(th)=0]'):
            scr = scrape_town(town, 
                              region=region, 
                              county=county, 
                              year=year, 
                              base_url=base_url)
            if scr is not None:
                result.append(scr)
    return result
    
    
def scrape_town(row, *, region, county, year, base_url) -> Dict[str, Any]:
    try:
        tds = row.find('td')
        town_name = tds[1].text
        results_link = tds[0].find('a', first=True).attrs['href']
        return scrape_results(base_url + results_link, 
                              region=region, 
                              county=county, 
                              year=year, 
                              town=town_name)
    except:
        print(f"Failed to parse town in {county}, {region}")
        return None


def scrape_results(url, *, region, county, year, town) -> Dict[str, Any]:
    session = HTMLSession()
    html = session.get(url).html
    html.encoding = 'ISO-8859-2'
    tables = html.find('table.table')
    stats = scrape_stats(tables[0])
    parties = concatenate(scrape_parties(t) for t in tables[1:])
    return {
        'year': year,
        'region': region,
        'county': county,
        'town': town,
        'parties': parties,
        'stats': stats
    }


def scrape_stats(table) -> Dict[str, Any]:
    data = table.find('tr > td')
    return {
        'registered': safe_parse_int(data[3].text), 
        'given': safe_parse_int(data[6].text), 
        'ok': safe_parse_int(data[7].text)
    }

    
def scrape_parties(table) -> List[Dict[str, Any]]:
    return [scrape_party(r) for r in table.find('tr') if not r.find('th')]

    
def scrape_party(row) -> Dict[str, Any]:
    tds = row.find('td')
    return {
        'name': tds[1].text,
        'votes': safe_parse_int(tds[2].text)
    }

    
def concatenate(ls) -> List[Any]:
    return [l for sl in ls for l in sl]


def get_year(url) -> int:
    return int(re.search(re.compile(r'ps(\d+).*/'), url).group(1))

def get_base_url(url):
    return re.match(re.compile(r'^.+\/'), url).group()

# %% [markdown]
# Zapsání dictionary s údaji o volbách do csv souboru.

# %%
def write_entries(entries, filename):
    flattened = flatten_entries(entries)
    with open(filename, 'w') as f:
        w = csv.DictWriter(f, all_columns(flattened))
        w.writeheader()
        w.writerows(flattened)


def flatten_entries(entries):
    flattened = []
    for entry in entries:
        result = {p['name']: p['votes'] for p in entry['parties']}
        result['year'] = entry['year']
        result['region'] = entry['region']
        result['county'] = entry['county']
        result['town'] = entry['town']
        result['voters'] = entry['stats']['registered']
        result['votes_ok'] = entry['stats']['ok']
        result['votes_all'] = entry['stats']['given']
        flattened.append(result)
    return flattened


def all_columns(dicts):
    base = ['year', 'region', 'county', 'town']
    end = ['voters', 'votes_ok', 'votes_all']
    columns = set()
    for d in dicts:
        for k in d.keys():
            if k not in base and k not in end:
                columns.add(k)
    return base + list(columns) + end

# %%
urls = [
    "https://volby.cz/pls/ps2010/ps3?xjazyk=CZ",
    "https://volby.cz/pls/ps2013/ps3?xjazyk=CZ",
    "https://volby.cz/pls/ps2017nss/ps3?xjazyk=CZ"
]

filenames = [
    "csv10.csv",
    "csv13.csv",
    "csv17.csv"
]

for filename, url in zip(filenames, urls):
    entries = scrape_counties17(url)
    with open(filename + ".json", 'w') as f:
        json.dump(entries, f)
    write_entries(entries, filename)
# Out:
# Scraped 57 towns in county Praha, Hlavní město Praha
# Scraped 114 towns in county Benešov, Středočeský kraj
# Failed to parse town in Beroun, Středočeský kraj
# Failed to parse town in Beroun, Středočeský kraj
# Scraped 85 towns in county Beroun, Středočeský kraj
# Failed to parse town in Kladno, Středočeský kraj
# Failed to parse town in Kladno, Středočeský kraj
# Scraped 100 towns in county Kladno, Středočeský kraj
# Failed to parse town in Kolín, Středočeský kraj
# Scraped 89 towns in county Kolín, Středočeský kraj
# Failed to parse town in Kutná Hora, Středočeský kraj
# Failed to parse town in Kutná Hora, Středočeský kraj
# Scraped 88 towns in county Kutná Hora, Středočeský kraj
# Scraped 69 towns in county Mělník, Středočeský kraj
# Scraped 120 towns in county Mladá Boleslav, Středočeský kraj
# Scraped 87 towns in county Nymburk, Středočeský kraj
# Failed to parse town in Praha-východ, Středočeský kraj
# Scraped 110 towns in county Praha-východ, Středočeský kraj
# Failed to parse town in Praha-západ, Středočeský kraj
# Failed to parse town in Praha-západ, Středočeský kraj
# Scraped 79 towns in county Praha-západ, Středočeský kraj
# Failed to parse town in Příbram, Středočeský kraj
# Failed to parse town in Příbram, Středočeský kraj
# Scraped 121 towns in county Příbram, Středočeský kraj
# Failed to parse town in Rakovník, Středočeský kraj
# Scraped 83 towns in county Rakovník, Středočeský kraj
# Failed to parse town in České Budějovice, Jihočeský kraj
# Failed to parse town in České Budějovice, Jihočeský kraj
# Scraped 109 towns in county České Budějovice, Jihočeský kraj
# Failed to parse town in Český Krumlov, Jihočeský kraj
# Failed to parse town in Český Krumlov, Jihočeský kraj
# Scraped 46 towns in county Český Krumlov, Jihočeský kraj
# Failed to parse town in Jindřichův Hradec, Jihočeský kraj
# Failed to parse town in Jindřichův Hradec, Jihočeský kraj
# Scraped 106 towns in county Jindřichův Hradec, Jihočeský kraj
# Scraped 75 towns in county Písek, Jihočeský kraj
# Failed to parse town in Prachatice, Jihočeský kraj
# Scraped 65 towns in county Prachatice, Jihočeský kraj
# Failed to parse town in Strakonice, Jihočeský kraj
# Failed to parse town in Strakonice, Jihočeský kraj
# Scraped 112 towns in county Strakonice, Jihočeský kraj
# Failed to parse town in Tábor, Jihočeský kraj
# Scraped 110 towns in county Tábor, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Failed to parse town in Zahraničí, Jihočeský kraj
# Scraped 14 towns in county Zahraničí, Jihočeský kraj
# Failed to parse town in Domažlice, Plzeňský kraj
# Failed to parse town in Domažlice, Plzeňský kraj
# Scraped 85 towns in county Domažlice, Plzeňský kraj
# Failed to parse town in Klatovy, Plzeňský kraj
# Failed to parse town in Klatovy, Plzeňský kraj
# Scraped 94 towns in county Klatovy, Plzeňský kraj
# Scraped 24 towns in county Plzeň-město, Plzeňský kraj
# Scraped 90 towns in county Plzeň-jih, Plzeňský kraj
# Failed to parse town in Plzeň-sever, Plzeňský kraj
# Scraped 98 towns in county Plzeň-sever, Plzeňský kraj
# Failed to parse town in Rokycany, Plzeňský kraj
# Scraped 68 towns in county Rokycany, Plzeňský kraj
# Scraped 51 towns in county Tachov, Plzeňský kraj
# Failed to parse town in Cheb, Karlovarský kraj
# Failed to parse town in Cheb, Karlovarský kraj
# Scraped 40 towns in county Cheb, Karlovarský kraj
# Scraped 54 towns in county Karlovy Vary, Karlovarský kraj
# Failed to parse town in Sokolov, Karlovarský kraj
# Scraped 38 towns in county Sokolov, Karlovarský kraj
# Failed to parse town in Děčín, Ústecký kraj
# Failed to parse town in Děčín, Ústecký kraj
# Scraped 52 towns in county Děčín, Ústecký kraj
# Failed to parse town in Chomutov, Ústecký kraj
# Scraped 44 towns in county Chomutov, Ústecký kraj
# Scraped 105 towns in county Litoměřice, Ústecký kraj
# Failed to parse town in Louny, Ústecký kraj
# Failed to parse town in Louny, Ústecký kraj
# Scraped 70 towns in county Louny, Ústecký kraj
# Failed to parse town in Most, Ústecký kraj
# Scraped 26 towns in county Most, Ústecký kraj
# Failed to parse town in Teplice, Ústecký kraj
# Failed to parse town in Teplice, Ústecký kraj
# Scraped 34 towns in county Teplice, Ústecký kraj
# Failed to parse town in Ústí nad Labem, Ústecký kraj
# Scraped 23 towns in county Ústí nad Labem, Ústecký kraj
# Scraped 57 towns in county Česká Lípa, Liberecký kraj
# Failed to parse town in Jablonec nad Nisou, Liberecký kraj
# Failed to parse town in Jablonec nad Nisou, Liberecký kraj
# Scraped 34 towns in county Jablonec nad Nisou, Liberecký kraj
# Failed to parse town in Liberec, Liberecký kraj
# Scraped 59 towns in county Liberec, Liberecký kraj
# Failed to parse town in Semily, Liberecký kraj
# Scraped 65 towns in county Semily, Liberecký kraj
# Failed to parse town in Hradec Králové, Královéhradecký kraj
# Scraped 104 towns in county Hradec Králové, Královéhradecký kraj
# Scraped 111 towns in county Jičín, Královéhradecký kraj
# Scraped 78 towns in county Náchod, Královéhradecký kraj
# Failed to parse town in Rychnov nad Kněžnou, Královéhradecký kraj
# Scraped 80 towns in county Rychnov nad Kněžnou, Královéhradecký kraj
# Scraped 75 towns in county Trutnov, Královéhradecký kraj
# Scraped 108 towns in county Chrudim, Pardubický kraj
# Failed to parse town in Pardubice, Pardubický kraj
# Failed to parse town in Pardubice, Pardubický kraj
# Scraped 112 towns in county Pardubice, Pardubický kraj
# Failed to parse town in Svitavy, Pardubický kraj
# Scraped 116 towns in county Svitavy, Pardubický kraj
# Failed to parse town in Ústí nad Orlicí, Pardubický kraj
# Failed to parse town in Ústí nad Orlicí, Pardubický kraj
# Scraped 115 towns in county Ústí nad Orlicí, Pardubický kraj
# Scraped 120 towns in county Havlíčkův Brod, Vysočina
# Scraped 123 towns in county Jihlava, Vysočina
# Scraped 120 towns in county Pelhřimov, Vysočina
# Failed to parse town in Třebíč, Vysočina
# Scraped 167 towns in county Třebíč, Vysočina
# Scraped 174 towns in county Žďár nad Sázavou, Vysočina
# Failed to parse town in Blansko, Jihomoravský kraj
# Scraped 116 towns in county Blansko, Jihomoravský kraj
# Failed to parse town in Brno-město, Jihomoravský kraj
# Scraped 29 towns in county Brno-město, Jihomoravský kraj
# Failed to parse town in Brno-venkov, Jihomoravský kraj
# Failed to parse town in Brno-venkov, Jihomoravský kraj
# Scraped 187 towns in county Brno-venkov, Jihomoravský kraj
# Scraped 63 towns in county Břeclav, Jihomoravský kraj
# Failed to parse town in Hodonín, Jihomoravský kraj
# Failed to parse town in Hodonín, Jihomoravský kraj
# Scraped 82 towns in county Hodonín, Jihomoravský kraj
# Failed to parse town in Vyškov, Jihomoravský kraj
# Scraped 80 towns in county Vyškov, Jihomoravský kraj
# Scraped 144 towns in county Znojmo, Jihomoravský kraj
# Scraped 24 towns in county Jeseník, Olomoucký kraj
# Scraped 96 towns in county Olomouc, Olomoucký kraj
# Failed to parse town in Prostějov, Olomoucký kraj
# Failed to parse town in Prostějov, Olomoucký kraj
# Scraped 97 towns in county Prostějov, Olomoucký kraj
# Failed to parse town in Přerov, Olomoucký kraj
# Scraped 104 towns in county Přerov, Olomoucký kraj
# Scraped 78 towns in county Šumperk, Olomoucký kraj
# Failed to parse town in Kroměříž, Zlínský kraj
# Failed to parse town in Kroměříž, Zlínský kraj
# Scraped 79 towns in county Kroměříž, Zlínský kraj
# Scraped 78 towns in county Uherské Hradiště, Zlínský kraj
# Failed to parse town in Vsetín, Zlínský kraj
# Scraped 59 towns in county Vsetín, Zlínský kraj
# Failed to parse town in Zlín, Zlínský kraj
# Scraped 89 towns in county Zlín, Zlínský kraj
# Failed to parse town in Bruntál, Moravskoslezský kraj
# Failed to parse town in Bruntál, Moravskoslezský kraj
# Scraped 67 towns in county Bruntál, Moravskoslezský kraj
# Scraped 72 towns in county Frýdek-Místek, Moravskoslezský kraj
# Failed to parse town in Karviná, Moravskoslezský kraj
# Scraped 17 towns in county Karviná, Moravskoslezský kraj
# Failed to parse town in Nový Jičín, Moravskoslezský kraj
# Scraped 53 towns in county Nový Jičín, Moravskoslezský kraj
# Failed to parse town in Opava, Moravskoslezský kraj
# Scraped 77 towns in county Opava, Moravskoslezský kraj
# Failed to parse town in Ostrava-město, Moravskoslezský kraj
# Scraped 35 towns in county Ostrava-město, Moravskoslezský kraj
# Scraped 57 towns in county Praha, Hlavní město Praha
# Scraped 114 towns in county Benešov, Středočeský kraj
# Failed to parse town in Beroun, Středočeský kraj
# Failed to parse town in Beroun, Středočeský kraj
# Scraped 85 towns in county Beroun, Středočeský kraj
# Failed to parse town in Kladno, Středočeský kraj
# Failed to parse town in Kladno, Středočeský kraj
# Scraped 100 towns in county Kladno, Středočeský kraj
# Failed to parse town in Kolín, Středočeský kraj
# Scraped 89 towns in county Kolín, Středočeský kraj
# Failed to parse town in Kutná Hora, Středočeský kraj
# Failed to parse town in Kutná Hora, Středočeský kraj
# Scraped 88 towns in county Kutná Hora, Středočeský kraj
# Scraped 69 towns in county Mělník, Středočeský kraj
# Scraped 120 towns in county Mladá Boleslav, Středočeský kraj
# Scraped 87 towns in county Nymburk, Středočeský kraj
# Failed to parse town in Praha-východ, Středočeský kraj
# Scraped 110 towns in county Praha-východ, Středočeský kraj
# Failed to parse town in Praha-západ, Středočeský kraj
# Failed to parse town in Praha-západ, Středočeský kraj
# Scraped 79 towns in county Praha-západ, Středočeský kraj
# Failed to parse town in Příbram, Středočeský kraj
# Failed to parse town in Příbram, Středočeský kraj
# Scraped 121 towns in county Příbram, Středočeský kraj
# Failed to parse town in Rakovník, Středočeský kraj
# Scraped 83 towns in county Rakovník, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Scraped 14 towns in county Zahraničí, Středočeský kraj
# Failed to parse town in České Budějovice, Jihočeský kraj
# Failed to parse town in České Budějovice, Jihočeský kraj
# Scraped 109 towns in county České Budějovice, Jihočeský kraj
# Failed to parse town in Český Krumlov, Jihočeský kraj
# Failed to parse town in Český Krumlov, Jihočeský kraj
# Scraped 46 towns in county Český Krumlov, Jihočeský kraj
# Failed to parse town in Jindřichův Hradec, Jihočeský kraj
# Failed to parse town in Jindřichův Hradec, Jihočeský kraj
# Scraped 106 towns in county Jindřichův Hradec, Jihočeský kraj
# Scraped 75 towns in county Písek, Jihočeský kraj
# Failed to parse town in Prachatice, Jihočeský kraj
# Scraped 65 towns in county Prachatice, Jihočeský kraj
# Failed to parse town in Strakonice, Jihočeský kraj
# Failed to parse town in Strakonice, Jihočeský kraj
# Scraped 112 towns in county Strakonice, Jihočeský kraj
# Failed to parse town in Tábor, Jihočeský kraj
# Scraped 110 towns in county Tábor, Jihočeský kraj
# Failed to parse town in Domažlice, Plzeňský kraj
# Failed to parse town in Domažlice, Plzeňský kraj
# Scraped 85 towns in county Domažlice, Plzeňský kraj
# Failed to parse town in Klatovy, Plzeňský kraj
# Failed to parse town in Klatovy, Plzeňský kraj
# Scraped 94 towns in county Klatovy, Plzeňský kraj
# Scraped 24 towns in county Plzeň-město, Plzeňský kraj
# Scraped 90 towns in county Plzeň-jih, Plzeňský kraj
# Failed to parse town in Plzeň-sever, Plzeňský kraj
# Scraped 98 towns in county Plzeň-sever, Plzeňský kraj
# Failed to parse town in Rokycany, Plzeňský kraj
# Scraped 68 towns in county Rokycany, Plzeňský kraj
# Scraped 51 towns in county Tachov, Plzeňský kraj
# Failed to parse town in Cheb, Karlovarský kraj
# Failed to parse town in Cheb, Karlovarský kraj
# Scraped 40 towns in county Cheb, Karlovarský kraj
# Scraped 54 towns in county Karlovy Vary, Karlovarský kraj
# Failed to parse town in Sokolov, Karlovarský kraj
# Scraped 38 towns in county Sokolov, Karlovarský kraj
# Failed to parse town in Děčín, Ústecký kraj
# Failed to parse town in Děčín, Ústecký kraj
# Scraped 52 towns in county Děčín, Ústecký kraj
# Failed to parse town in Chomutov, Ústecký kraj
# Scraped 44 towns in county Chomutov, Ústecký kraj
# Scraped 105 towns in county Litoměřice, Ústecký kraj
# Failed to parse town in Louny, Ústecký kraj
# Failed to parse town in Louny, Ústecký kraj
# Scraped 70 towns in county Louny, Ústecký kraj
# Failed to parse town in Most, Ústecký kraj
# Scraped 26 towns in county Most, Ústecký kraj
# Failed to parse town in Teplice, Ústecký kraj
# Failed to parse town in Teplice, Ústecký kraj
# Scraped 34 towns in county Teplice, Ústecký kraj
# Failed to parse town in Ústí nad Labem, Ústecký kraj
# Scraped 23 towns in county Ústí nad Labem, Ústecký kraj
# Scraped 57 towns in county Česká Lípa, Liberecký kraj
# Failed to parse town in Jablonec nad Nisou, Liberecký kraj
# Failed to parse town in Jablonec nad Nisou, Liberecký kraj
# Scraped 34 towns in county Jablonec nad Nisou, Liberecký kraj
# Failed to parse town in Liberec, Liberecký kraj
# Scraped 59 towns in county Liberec, Liberecký kraj
# Failed to parse town in Semily, Liberecký kraj
# Scraped 65 towns in county Semily, Liberecký kraj
# Failed to parse town in Hradec Králové, Královéhradecký kraj
# Scraped 104 towns in county Hradec Králové, Královéhradecký kraj
# Scraped 111 towns in county Jičín, Královéhradecký kraj
# Scraped 78 towns in county Náchod, Královéhradecký kraj
# Failed to parse town in Rychnov nad Kněžnou, Královéhradecký kraj
# Scraped 80 towns in county Rychnov nad Kněžnou, Královéhradecký kraj
# Scraped 75 towns in county Trutnov, Královéhradecký kraj
# Scraped 108 towns in county Chrudim, Pardubický kraj
# Failed to parse town in Pardubice, Pardubický kraj
# Failed to parse town in Pardubice, Pardubický kraj
# Scraped 112 towns in county Pardubice, Pardubický kraj
# Failed to parse town in Svitavy, Pardubický kraj
# Scraped 116 towns in county Svitavy, Pardubický kraj
# Failed to parse town in Ústí nad Orlicí, Pardubický kraj
# Failed to parse town in Ústí nad Orlicí, Pardubický kraj
# Scraped 115 towns in county Ústí nad Orlicí, Pardubický kraj
# Scraped 120 towns in county Havlíčkův Brod, Kraj Vysočina
# Scraped 123 towns in county Jihlava, Kraj Vysočina
# Scraped 120 towns in county Pelhřimov, Kraj Vysočina
# Failed to parse town in Třebíč, Kraj Vysočina
# Scraped 167 towns in county Třebíč, Kraj Vysočina
# Scraped 174 towns in county Žďár nad Sázavou, Kraj Vysočina
# Failed to parse town in Blansko, Jihomoravský kraj
# Scraped 116 towns in county Blansko, Jihomoravský kraj
# Failed to parse town in Brno-město, Jihomoravský kraj
# Scraped 29 towns in county Brno-město, Jihomoravský kraj
# Failed to parse town in Brno-venkov, Jihomoravský kraj
# Failed to parse town in Brno-venkov, Jihomoravský kraj
# Scraped 187 towns in county Brno-venkov, Jihomoravský kraj
# Scraped 63 towns in county Břeclav, Jihomoravský kraj
# Failed to parse town in Hodonín, Jihomoravský kraj
# Failed to parse town in Hodonín, Jihomoravský kraj
# Scraped 82 towns in county Hodonín, Jihomoravský kraj
# Failed to parse town in Vyškov, Jihomoravský kraj
# Scraped 80 towns in county Vyškov, Jihomoravský kraj
# Scraped 144 towns in county Znojmo, Jihomoravský kraj
# Scraped 24 towns in county Jeseník, Olomoucký kraj
# Scraped 96 towns in county Olomouc, Olomoucký kraj
# Failed to parse town in Prostějov, Olomoucký kraj
# Failed to parse town in Prostějov, Olomoucký kraj
# Scraped 97 towns in county Prostějov, Olomoucký kraj
# Failed to parse town in Přerov, Olomoucký kraj
# Scraped 104 towns in county Přerov, Olomoucký kraj
# Scraped 78 towns in county Šumperk, Olomoucký kraj
# Failed to parse town in Kroměříž, Zlínský kraj
# Failed to parse town in Kroměříž, Zlínský kraj
# Scraped 79 towns in county Kroměříž, Zlínský kraj
# Scraped 78 towns in county Uherské Hradiště, Zlínský kraj
# Failed to parse town in Vsetín, Zlínský kraj
# Failed to parse town in Vsetín, Zlínský kraj
# Scraped 61 towns in county Vsetín, Zlínský kraj
# Failed to parse town in Zlín, Zlínský kraj
# Scraped 89 towns in county Zlín, Zlínský kraj
# Failed to parse town in Bruntál, Moravskoslezský kraj
# Failed to parse town in Bruntál, Moravskoslezský kraj
# Scraped 67 towns in county Bruntál, Moravskoslezský kraj
# Scraped 72 towns in county Frýdek-Místek, Moravskoslezský kraj
# Failed to parse town in Karviná, Moravskoslezský kraj
# Scraped 17 towns in county Karviná, Moravskoslezský kraj
# Scraped 54 towns in county Nový Jičín, Moravskoslezský kraj
# Failed to parse town in Opava, Moravskoslezský kraj
# Scraped 77 towns in county Opava, Moravskoslezský kraj
# Failed to parse town in Ostrava-město, Moravskoslezský kraj
# Scraped 35 towns in county Ostrava-město, Moravskoslezský kraj
# Scraped 57 towns in county Praha, Hlavní město Praha
# Scraped 114 towns in county Benešov, Středočeský kraj
# Failed to parse town in Beroun, Středočeský kraj
# Failed to parse town in Beroun, Středočeský kraj
# Scraped 85 towns in county Beroun, Středočeský kraj
# Failed to parse town in Kladno, Středočeský kraj
# Failed to parse town in Kladno, Středočeský kraj
# Scraped 100 towns in county Kladno, Středočeský kraj
# Failed to parse town in Kolín, Středočeský kraj
# Scraped 89 towns in county Kolín, Středočeský kraj
# Failed to parse town in Kutná Hora, Středočeský kraj
# Failed to parse town in Kutná Hora, Středočeský kraj
# Scraped 88 towns in county Kutná Hora, Středočeský kraj
# Scraped 69 towns in county Mělník, Středočeský kraj
# Scraped 120 towns in county Mladá Boleslav, Středočeský kraj
# Scraped 87 towns in county Nymburk, Středočeský kraj
# Failed to parse town in Praha-východ, Středočeský kraj
# Scraped 110 towns in county Praha-východ, Středočeský kraj
# Failed to parse town in Praha-západ, Středočeský kraj
# Failed to parse town in Praha-západ, Středočeský kraj
# Scraped 79 towns in county Praha-západ, Středočeský kraj
# Scraped 120 towns in county Příbram, Středočeský kraj
# Failed to parse town in Rakovník, Středočeský kraj
# Scraped 83 towns in county Rakovník, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Failed to parse town in Zahraničí, Středočeský kraj
# Scraped 14 towns in county Zahraničí, Středočeský kraj
# Failed to parse town in České Budějovice, Jihočeský kraj
# Failed to parse town in České Budějovice, Jihočeský kraj
# Scraped 109 towns in county České Budějovice, Jihočeský kraj
# Failed to parse town in Český Krumlov, Jihočeský kraj
# Failed to parse town in Český Krumlov, Jihočeský kraj
# Scraped 46 towns in county Český Krumlov, Jihočeský kraj
# Failed to parse town in Jindřichův Hradec, Jihočeský kraj
# Failed to parse town in Jindřichův Hradec, Jihočeský kraj
# Scraped 106 towns in county Jindřichův Hradec, Jihočeský kraj
# Scraped 75 towns in county Písek, Jihočeský kraj
# Failed to parse town in Prachatice, Jihočeský kraj
# Scraped 65 towns in county Prachatice, Jihočeský kraj
# Failed to parse town in Strakonice, Jihočeský kraj
# Failed to parse town in Strakonice, Jihočeský kraj
# Scraped 112 towns in county Strakonice, Jihočeský kraj
# Failed to parse town in Tábor, Jihočeský kraj
# Scraped 110 towns in county Tábor, Jihočeský kraj
# Failed to parse town in Domažlice, Plzeňský kraj
# Failed to parse town in Domažlice, Plzeňský kraj
# Scraped 85 towns in county Domažlice, Plzeňský kraj
# Failed to parse town in Klatovy, Plzeňský kraj
# Failed to parse town in Klatovy, Plzeňský kraj
# Scraped 94 towns in county Klatovy, Plzeňský kraj
# Scraped 15 towns in county Plzeň-město, Plzeňský kraj
# Scraped 90 towns in county Plzeň-jih, Plzeňský kraj
# Failed to parse town in Plzeň-sever, Plzeňský kraj
# Scraped 98 towns in county Plzeň-sever, Plzeňský kraj
# Failed to parse town in Rokycany, Plzeňský kraj
# Scraped 68 towns in county Rokycany, Plzeňský kraj
# Scraped 51 towns in county Tachov, Plzeňský kraj
# Failed to parse town in Cheb, Karlovarský kraj
# Failed to parse town in Cheb, Karlovarský kraj
# Scraped 40 towns in county Cheb, Karlovarský kraj
# Failed to parse town in Karlovy Vary, Karlovarský kraj
# Failed to parse town in Karlovy Vary, Karlovarský kraj
# Scraped 55 towns in county Karlovy Vary, Karlovarský kraj
# Failed to parse town in Sokolov, Karlovarský kraj
# Scraped 38 towns in county Sokolov, Karlovarský kraj
# Failed to parse town in Děčín, Ústecký kraj
# Failed to parse town in Děčín, Ústecký kraj
# Scraped 52 towns in county Děčín, Ústecký kraj
# Failed to parse town in Chomutov, Ústecký kraj
# Scraped 44 towns in county Chomutov, Ústecký kraj
# Scraped 105 towns in county Litoměřice, Ústecký kraj
# Failed to parse town in Louny, Ústecký kraj
# Failed to parse town in Louny, Ústecký kraj
# Scraped 70 towns in county Louny, Ústecký kraj
# Failed to parse town in Most, Ústecký kraj
# Scraped 26 towns in county Most, Ústecký kraj
# Failed to parse town in Teplice, Ústecký kraj
# Failed to parse town in Teplice, Ústecký kraj
# Scraped 34 towns in county Teplice, Ústecký kraj
# Failed to parse town in Ústí nad Labem, Ústecký kraj
# Scraped 23 towns in county Ústí nad Labem, Ústecký kraj
# Scraped 57 towns in county Česká Lípa, Liberecký kraj
# Failed to parse town in Jablonec nad Nisou, Liberecký kraj
# Failed to parse town in Jablonec nad Nisou, Liberecký kraj
# Scraped 34 towns in county Jablonec nad Nisou, Liberecký kraj
# Failed to parse town in Liberec, Liberecký kraj
# Scraped 59 towns in county Liberec, Liberecký kraj
# Failed to parse town in Semily, Liberecký kraj
# Scraped 65 towns in county Semily, Liberecký kraj
# Failed to parse town in Hradec Králové, Královéhradecký kraj
# Scraped 104 towns in county Hradec Králové, Královéhradecký kraj
# Scraped 111 towns in county Jičín, Královéhradecký kraj
# Scraped 78 towns in county Náchod, Královéhradecký kraj
# Failed to parse town in Rychnov nad Kněžnou, Královéhradecký kraj
# Scraped 80 towns in county Rychnov nad Kněžnou, Královéhradecký kraj
# Scraped 75 towns in county Trutnov, Královéhradecký kraj
# Scraped 108 towns in county Chrudim, Pardubický kraj
# Failed to parse town in Pardubice, Pardubický kraj
# Failed to parse town in Pardubice, Pardubický kraj
# Scraped 112 towns in county Pardubice, Pardubický kraj
# Failed to parse town in Svitavy, Pardubický kraj
# Scraped 116 towns in county Svitavy, Pardubický kraj
# Failed to parse town in Ústí nad Orlicí, Pardubický kraj
# Failed to parse town in Ústí nad Orlicí, Pardubický kraj
# Scraped 115 towns in county Ústí nad Orlicí, Pardubický kraj
# Scraped 120 towns in county Havlíčkův Brod, Kraj Vysočina
# Scraped 123 towns in county Jihlava, Kraj Vysočina
# Scraped 120 towns in county Pelhřimov, Kraj Vysočina
# Failed to parse town in Třebíč, Kraj Vysočina
# Scraped 167 towns in county Třebíč, Kraj Vysočina
# Scraped 174 towns in county Žďár nad Sázavou, Kraj Vysočina
# Failed to parse town in Blansko, Jihomoravský kraj
# Scraped 116 towns in county Blansko, Jihomoravský kraj
# Scraped 1 towns in county Brno-město, Jihomoravský kraj
# Failed to parse town in Brno-venkov, Jihomoravský kraj
# Failed to parse town in Brno-venkov, Jihomoravský kraj
# Scraped 187 towns in county Brno-venkov, Jihomoravský kraj
# Scraped 63 towns in county Břeclav, Jihomoravský kraj
# Failed to parse town in Hodonín, Jihomoravský kraj
# Failed to parse town in Hodonín, Jihomoravský kraj
# Scraped 82 towns in county Hodonín, Jihomoravský kraj
# Failed to parse town in Vyškov, Jihomoravský kraj
# Failed to parse town in Vyškov, Jihomoravský kraj
# Scraped 79 towns in county Vyškov, Jihomoravský kraj
# Scraped 144 towns in county Znojmo, Jihomoravský kraj
# Scraped 24 towns in county Jeseník, Olomoucký kraj
# Failed to parse town in Olomouc, Olomoucký kraj
# Failed to parse town in Olomouc, Olomoucký kraj
# Scraped 97 towns in county Olomouc, Olomoucký kraj
# Failed to parse town in Prostějov, Olomoucký kraj
# Failed to parse town in Prostějov, Olomoucký kraj
# Scraped 97 towns in county Prostějov, Olomoucký kraj
# Scraped 105 towns in county Přerov, Olomoucký kraj
# Scraped 78 towns in county Šumperk, Olomoucký kraj
# Failed to parse town in Kroměříž, Zlínský kraj
# Failed to parse town in Kroměříž, Zlínský kraj
# Scraped 79 towns in county Kroměříž, Zlínský kraj
# Scraped 78 towns in county Uherské Hradiště, Zlínský kraj
# Failed to parse town in Vsetín, Zlínský kraj
# Failed to parse town in Vsetín, Zlínský kraj
# Scraped 61 towns in county Vsetín, Zlínský kraj
# Failed to parse town in Zlín, Zlínský kraj
# Scraped 89 towns in county Zlín, Zlínský kraj
# Failed to parse town in Bruntál, Moravskoslezský kraj
# Failed to parse town in Bruntál, Moravskoslezský kraj
# Scraped 67 towns in county Bruntál, Moravskoslezský kraj
# Scraped 72 towns in county Frýdek-Místek, Moravskoslezský kraj
# Failed to parse town in Karviná, Moravskoslezský kraj
# Scraped 17 towns in county Karviná, Moravskoslezský kraj
# Scraped 54 towns in county Nový Jičín, Moravskoslezský kraj
# Failed to parse town in Opava, Moravskoslezský kraj
# Scraped 77 towns in county Opava, Moravskoslezský kraj
# Failed to parse town in Ostrava-město, Moravskoslezský kraj
# Failed to parse town in Ostrava-město, Moravskoslezský kraj
# Scraped 13 towns in county Ostrava-město, Moravskoslezský kraj

# %%
urls = [
    "https://volby.cz/pls/ps1996/u53",
    "https://volby.cz/pls/ps1998/u53"
]

filenames = [
    "csv96_.csv",
    "csv98_.csv"
]

for filename, url in zip(filenames, urls):
    entries = scrape_counties02(url)
    with open(filename + ".json", 'w') as f:
        json.dump(entries, f)
    write_entries(entries, filename)
# Out:
# Written 1 towns from Praha I, Praha  (1996)
# Written 1 towns from Praha II, Praha  (1996)
# Written 1 towns from Praha III, Praha  (1996)
# Written 1 towns from Praha IV, Praha  (1996)
# Written 9 towns from Praha V, Praha  (1996)
# Written 6 towns from Praha VI, Praha  (1996)
# Written 2 towns from Praha VII, Praha  (1996)
# Written 4 towns from Praha VIII, Praha  (1996)
# Written 13 towns from Praha IX, Praha  (1996)
# Written 12 towns from Praha X, Praha  (1996)
# Written 4 towns from Praha XI, Praha  (1996)
# Written 2 towns from Praha XII, Praha  (1996)
# Written 1 towns from Praha XIII, Praha  (1996)
# Written 114 towns from Benešov, Středočeský kraj  (1996)
# Written 86 towns from Beroun, Středočeský kraj  (1996)
# Written 100 towns from Kladno, Středočeský kraj  (1996)
# Written 100 towns from Kolín, Středočeský kraj  (1996)
# Written 89 towns from Kutná Hora, Středočeský kraj  (1996)
# Written 70 towns from Mělník, Středočeský kraj  (1996)
# Written 122 towns from Mladá Boleslav, Středočeský kraj  (1996)
# Written 90 towns from Nymburk, Středočeský kraj  (1996)
# Written 91 towns from Praha-východ, Středočeský kraj  (1996)
# Written 80 towns from Praha-západ, Středočeský kraj  (1996)
# Written 120 towns from Příbram, Středočeský kraj  (1996)
# Written 85 towns from Rakovník, Středočeský kraj  (1996)
# Written 107 towns from České Budějovice, Jihočeský kraj  (1996)
# Written 46 towns from Český Krumlov, Jihočeský kraj  (1996)
# Written 106 towns from Jindřichův Hradec, Jihočeský kraj  (1996)
# Failed to parse town Polesí from Pelhřimov, Jihočeský kraj
# Written 119 towns from Pelhřimov, Jihočeský kraj  (1996)
# Written 76 towns from Písek, Jihočeský kraj  (1996)
# Written 65 towns from Prachatice, Jihočeský kraj  (1996)
# Written 112 towns from Strakonice, Jihočeský kraj  (1996)
# Written 111 towns from Tábor, Jihočeský kraj  (1996)
# Written 86 towns from Domažlice, Západočeský kraj  (1996)
# Written 39 towns from Cheb, Západočeský kraj  (1996)
# Written 54 towns from Karlovy Vary, Západočeský kraj  (1996)
# Written 98 towns from Klatovy, Západočeský kraj  (1996)
# Written 1 towns from Plzeň-město, Západočeský kraj  (1996)
# Written 100 towns from Plzeň-jih, Západočeský kraj  (1996)
# Written 102 towns from Plzeň-sever, Západočeský kraj  (1996)
# Written 68 towns from Rokycany, Západočeský kraj  (1996)
# Written 38 towns from Sokolov, Západočeský kraj  (1996)
# Written 50 towns from Tachov, Západočeský kraj  (1996)
# Written 60 towns from Česká Lípa, Severočeský kraj  (1996)
# Written 51 towns from Děčín, Severočeský kraj  (1996)
# Written 44 towns from Chomutov, Severočeský kraj  (1996)
# Written 34 towns from Jablonec n.Nisou, Severočeský kraj  (1996)
# Written 57 towns from Liberec, Severočeský kraj  (1996)
# Written 105 towns from Litoměřice, Severočeský kraj  (1996)
# Written 70 towns from Louny, Severočeský kraj  (1996)
# Written 26 towns from Most, Severočeský kraj  (1996)
# Written 34 towns from Teplice, Severočeský kraj  (1996)
# Written 22 towns from Ústí n.Labem, Severočeský kraj  (1996)
# Written 119 towns from Havlíčkův Brod, Východočeský kraj  (1996)
# Written 101 towns from Hradec Králové, Východočeský kraj  (1996)
# Written 112 towns from Chrudim, Východočeský kraj  (1996)
# Written 111 towns from Jičín, Východočeský kraj  (1996)
# Written 78 towns from Náchod, Východočeský kraj  (1996)
# Written 115 towns from Pardubice, Východočeský kraj  (1996)
# Written 83 towns from Rychnov n.Kněžnou, Východočeský kraj  (1996)
# Written 65 towns from Semily, Východočeský kraj  (1996)
# Written 113 towns from Svitavy, Východočeský kraj  (1996)
# Written 75 towns from Trutnov, Východočeský kraj  (1996)
# Written 111 towns from Ústí n.Orlicí, Východočeský kraj  (1996)
# Written 129 towns from Blansko, Jihomoravský kraj  (1996)
# Written 1 towns from Brno-město, Jihomoravský kraj  (1996)
# Written 137 towns from Brno-venkov, Jihomoravský kraj  (1996)
# Written 68 towns from Břeclav, Jihomoravský kraj  (1996)
# Written 82 towns from Zlín, Jihomoravský kraj  (1996)
# Written 81 towns from Hodonín, Jihomoravský kraj  (1996)
# Written 121 towns from Jihlava, Jihomoravský kraj  (1996)
# Written 79 towns from Kroměříž, Jihomoravský kraj  (1996)
# Written 95 towns from Prostějov, Jihomoravský kraj  (1996)
# Written 173 towns from Třebíč, Jihomoravský kraj  (1996)
# Written 78 towns from Uherské Hradiště, Jihomoravský kraj  (1996)
# Written 80 towns from Vyškov, Jihomoravský kraj  (1996)
# Written 147 towns from Znojmo, Jihomoravský kraj  (1996)
# Written 197 towns from Žďár n.Sázavou, Jihomoravský kraj  (1996)
# Written 71 towns from Bruntál, Severomoravský kraj  (1996)
# Written 75 towns from Frýdek-Místek, Severomoravský kraj  (1996)
# Written 15 towns from Karviná, Severomoravský kraj  (1996)
# Written 55 towns from Nový Jičín, Severomoravský kraj  (1996)
# Written 93 towns from Olomouc, Severomoravský kraj  (1996)
# Written 80 towns from Opava, Severomoravský kraj  (1996)
# Written 1 towns from Ostrava-město, Severomoravský kraj  (1996)
# Written 103 towns from Přerov, Severomoravský kraj  (1996)
# Written 78 towns from Šumperk, Severomoravský kraj  (1996)
# Written 58 towns from Vsetín, Severomoravský kraj  (1996)
# Written 23 towns from Jeseník, Severomoravský kraj  (1996)
# Written 1 towns from Praha I, Praha  (1998)
# Written 1 towns from Praha II, Praha  (1998)
# Written 1 towns from Praha III, Praha  (1998)
# Written 1 towns from Praha IV, Praha  (1998)
# Written 9 towns from Praha V, Praha  (1998)
# Written 6 towns from Praha VI, Praha  (1998)
# Written 2 towns from Praha VII, Praha  (1998)
# Written 4 towns from Praha VIII, Praha  (1998)
# Written 13 towns from Praha IX, Praha  (1998)
# Written 12 towns from Praha X, Praha  (1998)
# Written 4 towns from Praha XI, Praha  (1998)
# Written 2 towns from Praha XII, Praha  (1998)
# Written 1 towns from Praha XIII, Praha  (1998)
# Written 114 towns from Benešov, Středočeský kraj  (1998)
# Written 86 towns from Beroun, Středočeský kraj  (1998)
# Written 100 towns from Kladno, Středočeský kraj  (1998)
# Written 100 towns from Kolín, Středočeský kraj  (1998)
# Written 89 towns from Kutná Hora, Středočeský kraj  (1998)
# Written 70 towns from Mělník, Středočeský kraj  (1998)
# Written 122 towns from Mladá Boleslav, Středočeský kraj  (1998)
# Written 90 towns from Nymburk, Středočeský kraj  (1998)
# Written 91 towns from Praha-východ, Středočeský kraj  (1998)
# Written 80 towns from Praha-západ, Středočeský kraj  (1998)
# Written 120 towns from Příbram, Středočeský kraj  (1998)
# Written 85 towns from Rakovník, Středočeský kraj  (1998)
# Written 107 towns from České Budějovice, Jihočeský kraj  (1998)
# Written 46 towns from Český Krumlov, Jihočeský kraj  (1998)
# Written 106 towns from Jindřichův Hradec, Jihočeský kraj  (1998)
# Written 120 towns from Pelhřimov, Jihočeský kraj  (1998)
# Written 76 towns from Písek, Jihočeský kraj  (1998)
# Written 65 towns from Prachatice, Jihočeský kraj  (1998)
# Written 112 towns from Strakonice, Jihočeský kraj  (1998)
# Written 111 towns from Tábor, Jihočeský kraj  (1998)
# Written 86 towns from Domažlice, Západočeský kraj  (1998)
# Written 39 towns from Cheb, Západočeský kraj  (1998)
# Written 54 towns from Karlovy Vary, Západočeský kraj  (1998)
# Written 98 towns from Klatovy, Západočeský kraj  (1998)
# Written 1 towns from Plzeň-město, Západočeský kraj  (1998)
# Written 100 towns from Plzeň-jih, Západočeský kraj  (1998)
# Written 102 towns from Plzeň-sever, Západočeský kraj  (1998)
# Written 68 towns from Rokycany, Západočeský kraj  (1998)
# Written 38 towns from Sokolov, Západočeský kraj  (1998)
# Written 50 towns from Tachov, Západočeský kraj  (1998)
# Written 60 towns from Česká Lípa, Severočeský kraj  (1998)
# Written 52 towns from Děčín, Severočeský kraj  (1998)
# Written 44 towns from Chomutov, Severočeský kraj  (1998)
# Written 34 towns from Jablonec n.Nisou, Severočeský kraj  (1998)
# Written 57 towns from Liberec, Severočeský kraj  (1998)
# Written 105 towns from Litoměřice, Severočeský kraj  (1998)
# Written 70 towns from Louny, Severočeský kraj  (1998)
# Written 26 towns from Most, Severočeský kraj  (1998)
# Written 34 towns from Teplice, Severočeský kraj  (1998)
# Written 23 towns from Ústí n.Labem, Severočeský kraj  (1998)
# Written 120 towns from Havlíčkův Brod, Východočeský kraj  (1998)
# Written 101 towns from Hradec Králové, Východočeský kraj  (1998)
# Written 112 towns from Chrudim, Východočeský kraj  (1998)
# Written 111 towns from Jičín, Východočeský kraj  (1998)
# Written 78 towns from Náchod, Východočeský kraj  (1998)
# Written 115 towns from Pardubice, Východočeský kraj  (1998)
# Written 83 towns from Rychnov n.Kněžnou, Východočeský kraj  (1998)
# Written 65 towns from Semily, Východočeský kraj  (1998)
# Written 113 towns from Svitavy, Východočeský kraj  (1998)
# Written 75 towns from Trutnov, Východočeský kraj  (1998)
# Written 112 towns from Ústí n.Orlicí, Východočeský kraj  (1998)
# Written 129 towns from Blansko, Jihomoravský kraj  (1998)
# Written 1 towns from Brno-město, Jihomoravský kraj  (1998)
# Written 137 towns from Brno-venkov, Jihomoravský kraj  (1998)
# Written 69 towns from Břeclav, Jihomoravský kraj  (1998)
# Written 82 towns from Zlín, Jihomoravský kraj  (1998)
# Written 81 towns from Hodonín, Jihomoravský kraj  (1998)
# Written 121 towns from Jihlava, Jihomoravský kraj  (1998)
# Written 79 towns from Kroměříž, Jihomoravský kraj  (1998)
# Written 95 towns from Prostějov, Jihomoravský kraj  (1998)
# Written 173 towns from Třebíč, Jihomoravský kraj  (1998)
# Written 78 towns from Uherské Hradiště, Jihomoravský kraj  (1998)
# Written 80 towns from Vyškov, Jihomoravský kraj  (1998)
# Written 148 towns from Znojmo, Jihomoravský kraj  (1998)
# Written 197 towns from Žďár n.Sázavou, Jihomoravský kraj  (1998)
# Written 71 towns from Bruntál, Severomoravský kraj  (1998)
# Written 75 towns from Frýdek-Místek, Severomoravský kraj  (1998)
# Written 16 towns from Karviná, Severomoravský kraj  (1998)
# Written 56 towns from Nový Jičín, Severomoravský kraj  (1998)
# Written 93 towns from Olomouc, Severomoravský kraj  (1998)
# Written 81 towns from Opava, Severomoravský kraj  (1998)
# Written 1 towns from Ostrava-město, Severomoravský kraj  (1998)
# Written 103 towns from Přerov, Severomoravský kraj  (1998)
# Written 78 towns from Šumperk, Severomoravský kraj  (1998)
# Written 58 towns from Vsetín, Severomoravský kraj  (1998)
# Written 23 towns from Jeseník, Severomoravský kraj  (1998)
